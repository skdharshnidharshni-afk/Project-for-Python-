# %% [markdown]
# <a href="https://colab.research.google.com/github/skdharshnidharshni-afk/Project-for-Python-/blob/main/Day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
marks=[45,34,87,95,78,43,65,18,91,38,50,85]
plt.hist(marks)
plt.title("student marks distribution")
plt.xlabel("marks")
plt.ylabel("number of students")
plt.show()

# %%
hours=[1,2,3,4,5,6,7,8]
marks=[45,47,56,60,67,70,78,89]
plt.scatter(hours,marks)
plt.title("study hours vs marks")
plt.xlabel("study hours")
plt.ylabel("marks")
plt.show()

# %%
import matplotlib. pyplot as plt
plt.subplot(1,2,1)
plt.plot([1,2,3],[10,20,30])
plt.title("graph 1")
plt.subplot(1,2,2)
plt.plot([1,2,3],[30,20,10])
plt.title("graph 2")
plt.show()
