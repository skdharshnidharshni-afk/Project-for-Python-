# %% [markdown]
# <a href="https://colab.research.google.com/github/skdharshnidharshni-afk/Project-for-Python-/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mark1=int(input("Enter M1:"))
Mark2=int(input("Enter M2:"))
Mark3=int(input("Enter M3:"))

total = Mark1 + Mark2 + Mark3
Average=total/3

print("total:",total)
print("Average:",Average)

if Average >= 90:
    print("Grade: A")
elif Average >= 50:
    print("Grade: B")
else:
    print("Grade: C")
# Out:
# Enter M1:57
# Enter M2:97
# Enter M3:08
# total: 162
# Average: 54.0
# Grade: B
