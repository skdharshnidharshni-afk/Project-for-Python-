# %% [markdown]
# <a href="https://colab.research.google.com/github/skdharshnidharshni-afk/Project-for-Python-/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
marks = np.array([90,87,67,94,67])
print(marks[3])
# Out:
# 94

# %%
marks = np.array([90,67,89,35,75])
print(marks[1:2])
# Out:
# [67]

# %%
scores = [58,78,45,75,98]

total = sum(scores)
average = total/len(scores)
highest = max(scores)
lowest = min(scores)

print("students scores:",scores)
print("total marks:",total)
print("average marks:",average)
print("highest marks:",highest)
print("lowest marks:",lowest)
# Out:
# students scores: [58, 78, 45, 75, 98]
# total marks: 354
# average marks: 70.8
# highest marks: 98
# lowest marks: 45
