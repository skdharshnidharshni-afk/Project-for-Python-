# %% [markdown]
# <a href="https://colab.research.google.com/github/skdharshnidharshni-afk/Project-for-Python-/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
   num=int(input("Enter number:"))
   print(num)
except:
  print("Invalid input")
# Out:
# Enter number:Ppp
# Invalid input
