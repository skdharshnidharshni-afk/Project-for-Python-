# %% [markdown]
# <a href="https://colab.research.google.com/github/skdharshnidharshni-afk/Project-for-Python-/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([1,3,5,7,9,8])
new_arr = arr.reshape(2,3)
print(new_arr)
# Out:
# [[1 3 5]
#  [7 9 8]]

# %%
sales = [1000,2000,3000,4000,6000,8000]

total_sales=sum(sales)
average_sales=total_sales/len(sales)
highest_sales=max(sales)
lowest_sales=min(sales)

print("Monthly sales:",sales)
print("total sales:",total_sales)
print("average sales:",average_sales)
print("highest sales:",highest_sales)
print("lowest sales:",lowest_sales)
# Out:
# Monthly sales: [1000, 2000, 3000, 4000, 6000, 8000]
# total sales: 24000
# average sales: 4000.0
# highest sales: 8000
# lowest sales: 1000
