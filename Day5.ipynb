# %% [markdown]
# <a href="https://colab.research.google.com/github/skdharshnidharshni-afk/Project-for-Python-/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.Series([10,20,30,40,50])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = pd.Series(
    [100,300,500],
    index=["arun","babu","priya"]
    )
print(data)
# Out:
# arun     100
# babu     300
# priya    500
# dtype: int64

# %%
employee={
"ID":[101,102,103],
"Name":["arun","Kumar","priya"],
"Salary":[50000,60000,70000]
}
df=pd.DataFrame(employee)
print(df)
# Out:
#     ID   Name  Salary
# 0  101   arun   50000
# 1  102  Kumar   60000
# 2  103  priya   70000
