# %% [markdown]
# <a href="https://colab.research.google.com/github/skdharshnidharshni-afk/Project-for-Python-/blob/main/Day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
"region":["north","south","west",],
"product":["labtop","mobile","tab"],
"sales":[25000,15000,76000]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   region product  sales
# 0  north  labtop  25000
# 1  south  mobile  15000
# 2   west     tab  76000

# %%
print(df['sales'].sum())

116000

print(df['sales'].max())

76000

print(df['sales'].min())

15000

print(df['sales'].count())

3
# Out:
# 116000
# 76000
# 15000
# 3
# 3
